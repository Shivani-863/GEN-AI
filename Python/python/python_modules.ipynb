# %%
import datetime
x=datetime.datetime.now()
print(x)
y=datetime.datetime.now().day
print(y)
z=datetime.datetime.now().date()
print(z)
a=datetime.datetime.now().ctime()  
print(a)
b=datetime.datetime.now().time()
print(b)
print(x.year)
print(x.strftime("%A"))    # Returns the day of week
# The datetime object has a method for formatting date objects into readable strings.
# The method is called strftime(), and takes one parameter, format, to specify the format of the returned string:
# Out:
# 2026-05-15 08:03:05.138963
# 15
# 2026-05-15
# Fri May 15 08:03:05 2026
# 08:03:05.139182
# 2026
# Friday
