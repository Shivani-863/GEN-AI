# %% [markdown]
# ### Dataframes --> Data sets in Pandas are usually multi-dimensional tables, called DataFrames.

# %%
# A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.
import pandas as pd
data={
    "names": ["Shiva", "Suresh", "Ramesh"],
    "ages": [25, 30, 35]
}
myvar=pd.DataFrame(data)
print(myvar)
print(myvar["names"])
print(myvar.loc[0])
# Out:
#     names  ages
# 0   Shiva    25
# 1  Suresh    30
# 2  Ramesh    35
# 0     Shiva
# 1    Suresh
# 2    Ramesh
# Name: names, dtype: str
# names    Shiva
# ages        25
# Name: 0, dtype: object

# %%
myvar=pd.DataFrame(data, index=["rank1", "rank2", "rank3"])
print(myvar)
print(myvar.loc["rank2"])
print(myvar.max())
# Out:
#         names  ages
# rank1   Shiva    25
# rank2  Suresh    30
# rank3  Ramesh    35
# names    Suresh
# ages         30
# Name: rank2, dtype: object
# names    Suresh
# ages         35
# dtype: object

# %%
df=pd.read_csv("data.csv")
print(df)
# Out:
#    EmployeeID    Name Department  Age  Salary  Experience
# 0         101    Amit         IT   25   45000           2
# 1         102   Priya         HR   28   50000           4
# 2         103   Rahul    Finance   32   65000           7
# 3         104   Sneha         IT   27   55000           3
# 4         105  Vikram  Marketing   30   60000           5
# 5         106  Anjali         HR   26   48000           2
# 6         107   Karan    Finance   35   75000          10
# 7         108    Neha  Marketing   29   58000           4
# 8         109   Arjun         IT   31   70000           8
# 9         110   Pooja         HR   24   42000           1
